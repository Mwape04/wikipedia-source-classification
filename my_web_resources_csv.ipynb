# %%
import pandas as pd

# Sample dataset
data = {
    "url": [
        "https://example.com/article1",
        "https://example.com/image1",
        "https://example.com/video1",
        "https://example.com/article2",
        "https://example.com/reference1"
    ],
    "title": [
        "History of Zambia",
        "Beautiful Landscape",
        "AI Tutorial Video",
        "Zambian Culture",
        "Wikipedia Reference Page"
    ],
    "resource_type": [
        "Article", "Image", "Video", "Article", "Reference"
    ],
    "word_count": [1200, 0, 0, 850, 0],
    "num_images": [5, 1, 3, 2, 0],
    "num_links": [10, 2, 5, 7, 15]
}

df = pd.DataFrame(data)

# Save as CSV (optional)
df.to_csv("my_web_resources.csv", index=False)

# Show first 5 rows
df.head()
# Out:
#                               url                     title resource_type  \
# 0    https://example.com/article1         History of Zambia       Article
# 1      https://example.com/image1       Beautiful Landscape         Image
# 2      https://example.com/video1         AI Tutorial Video         Video
# 3    https://example.com/article2           Zambian Culture       Article
# 4  https://example.com/reference1  Wikipedia Reference Page     Reference
#
#    word_count  num_images  num_links
# 0        1200           5         10
# 1           0           1          2
# 2           0           3          5
# 3         850           2          7
# 4           0           0         15
